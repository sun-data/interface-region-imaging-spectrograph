# %%
import pathlib
import astropy.units as u
import astropy.time
import astropy.wcs
import astropy.io.fits


def split_cubes(
    path_source: list[str | pathlib.Path],
    directory_destination: str | pathlib.Path,
) -> list[str | pathlib.Path]:
    """
    Split fits files containing wavelength, x, and y axes into separate fits files
    containing only wavelength and y axes.
    
    Parameters
    ----------
    path_source
        A list of paths to source files to be converted
    directory_destination
        A directory in which to place the results.
    """
    
    directory_destination = pathlib.Path(directory_destination)
    directory_destination.mkdir(exist_ok=True, parents=True)
    
    for path in path_source:
        
        path = pathlib.Path(path)
        
        hdul = astropy.io.fits.open(path)
        
        index_main = 0
        index_aux1 = ~1
        index_aux2 = ~2
        index_image = slice(index_main + 1, index_aux1)
        
        hdu_main = hdul[index_main]
        hdu_image = hdul[index_image]
        hdu_aux1 = hdul[index_aux1]
        hdu_aux2 = hdul[index_aux2]
        
        num_steps = hdu_main.header["NEXP"]
        
        date_obs = astropy.time.Time(hdu_main.header["DATE_OBS"])
        time = date_obs + hdu_aux1.data[..., hdu_aux1.header["TIME"]] * u.s
        
        for step in range(num_steps):
                
            
            slice_step = slice(step, step + 1)
            
            hdu_step_main = hdu_main.copy()
            hdu_step_main.header["DATE_OBS"] = time[step].fits
            
            hdu_step_image = [hdu.copy() for hdu in hdu_image]
            for hdu in hdu_step_image:
                wcs = astropy.wcs.WCS(hdu.header)
                
                if step == 0:
                    print(f"{wcs.wcs.crval}")
                
                hdu.header.update(wcs[slice_step].to_header())
                hdu.data = hdu.data[slice_step]
                
            hdu_step_aux1 = hdu_aux1.copy()
            hdu_step_aux1.data = hdu_step_aux1.data[slice_step]
            
            hdu_step_aux2 = hdu_aux2.copy()
            
            hdul_step = [hdu_step_main] + hdu_step_image + [hdu_step_aux1, hdu_step_aux2]
            hdul_step = astropy.io.fits.HDUList(hdul_step)
            
            filename = directory_destination / f"{path.stem}_s{step}{path.suffix}"
            
            hdul_step.writeto(filename, overwrite=True)

# %%
directory_source = pathlib.Path(r"C:\Users\byrdie\Kankelborg-Group\interface-region-imaging-spectrograph\iris_l2_20240222_214410_3680334922_raster")
path_source = sorted(list(directory_source.glob("*")))

split_cubes(
    path_source=path_source[:10],
    directory_destination=r"C:\Users\byrdie\Kankelborg-Group\interface-region-imaging-spectrograph\iris_l2_20240222_214410_3680334922_raster_split"
)
# Out:
# [ 1.33168977e-07  1.05176389e-01 -1.30635000e-01]
# [ 1.38067031e-07  1.05176389e-01 -1.30635000e-01]
# [ 2.78361509e-07  1.05176389e-01 -1.30635000e-01]
# [ 1.33168977e-07  1.05177778e-01 -1.30632222e-01]
# [ 1.38067031e-07  1.05177778e-01 -1.30632222e-01]
# [ 2.78361509e-07  1.05177778e-01 -1.30632222e-01]
# [ 1.33168977e-07  1.05190556e-01 -1.30610833e-01]
# [ 1.38067031e-07  1.05190556e-01 -1.30610833e-01]
# [ 2.78361509e-07  1.05190556e-01 -1.30610833e-01]
# [ 1.33168977e-07  1.05181111e-01 -1.30621389e-01]
# [ 1.38067031e-07  1.05181111e-01 -1.30621389e-01]
# [ 2.78361509e-07  1.05181111e-01 -1.30621389e-01]
# [ 1.33168977e-07  1.05188611e-01 -1.30604444e-01]
# [ 1.38067031e-07  1.05188611e-01 -1.30604444e-01]
# [ 2.78361509e-07  1.05188611e-01 -1.30604444e-01]
# [ 1.33168977e-07  1.05194722e-01 -1.30598611e-01]
# [ 1.38067031e-07  1.05194722e-01 -1.30598611e-01]
# [ 2.78361509e-07  1.05194722e-01 -1.30598611e-01]
# [ 1.33168977e-07  1.05189444e-01 -1.30591389e-01]
# [ 1.38067031e-07  1.05189444e-01 -1.30591389e-01]
# [ 2.78361509e-07  1.05189444e-01 -1.30591389e-01]
# [ 1.33168977e-07  1.05184444e-01 -1.30578333e-01]
# [ 1.38067031e-07  1.05184444e-01 -1.30578333e-01]
# [ 2.78361509e-07  1.05184444e-01 -1.30578333e-01]
# [ 1.33168977e-07  1.05188611e-01 -1.30572222e-01]
# [ 1.38067031e-07  1.05188611e-01 -1.30572222e-01]
# [ 2.78361509e-07  1.05188611e-01 -1.30572222e-01]
# [ 1.33168977e-07  1.05180833e-01 -1.30561667e-01]
# [ 1.38067031e-07  1.05180833e-01 -1.30561667e-01]
# [ 2.78361509e-07  1.05180833e-01 -1.30561667e-01]

# %%
hdul = astropy.io.fits.open(r"C:\Users\byrdie\Kankelborg-Group\interface-region-imaging-spectrograph\iris_l2_20240209_011103_3650105103_raster\iris_l2_20240209_011103_3650105103_raster_t000_r00000.fits")

# %%
print(repr(hdul[0].header))
# Out:
# SIMPLE  =                    T / Written by IDL:  Thu Apr 11 11:22:44 2024
# BITPIX  =                   16 / Number of bits per data pixel
# NAXIS   =                    0 / Number of data axes
# EXTEND  =                    T / FITS data may contain extensions
# DATE    = '2024-04-11'         / Creation UTC (CCCC-MM-DD) date of FITS header
# COMMENT FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT and Astrophysics', volume 376, page 359; bibcode 2001A&A...376..359H
# TELESCOP= 'IRIS    '           /
# INSTRUME= 'SPEC    '           /
# DATA_LEV=              2.00000 /
# LVL_NUM =              2.00000 /
# VER_RF2 = 'L12-2019-08-08'     /
# DATE_RF2= '2024-04-11T17:58:53.844' /
# DATA_SRC=              1.51001 /
# ORIGIN  = 'SDO     '           /
# BLD_VERS= 'V9R5X   '           /
# LUTID   =              0.00000 /
# OBSID   = '3650105103'         /
# OBS_DESC= 'Large sit-and-stare 0.3x120 1s  C II   Si IV   Mg II h/k Deep x 2 Sp'
# OBSLABEL= '        '           /
# OBSTITLE= '        '           /
# DATE_OBS= '2024-02-09T01:11:03.184' /
# DATE_END= '2024-02-09T01:25:04.283' /
# STARTOBS= '2024-02-09T01:11:03.013' /
# ENDOBS  = '2024-02-09T01:25:07.307' /
# OBSREP  =                   69 /
# CAMERA  =                    1 /
# STATUS  = 'Final   '           /
# BTYPE   = 'Intensity'          /
# BUNIT   = 'Corrected DN'       /
# BSCALE  =                 0.25 /
# BZERO   =                 7992 /
# HLZ     =                    0 /
# SAA     = '           0'       /
# SAT_ROT =          0.000984038 /
# AECNOBS =                    0 /
# AECNRAS =                    0 /
# DSUN_OBS=          1.47579E+11 /
# IAECEVFL= 'NO      '           /
# IAECFLAG= 'NO      '           /
# IAECFLFL= 'NO      '           /
# TR_MODE = '        '           /
# FOVY    =              128.090 /
# FOVX    =             0.332700 /
# XCEN    =              347.637 /
# YCEN    =             -1.84508 /
# SUMSPTRL=                    0 /
# SUMSPTRN=                    2 /
# SUMSPTRF=                    2 /
# SUMSPAT =                    2 /
# EXPTIME =              1.99954 /
# EXPMIN  =              1.99945 /
# EXPMAX  =              1.99965 /
# DATAMEAN=              15.3942 /
# DATARMS =              29.7923 /
# DATAMEDN=              7.12913 /
# DATAMIN =             -1260.72 /
# DATAMAX =              12952.7 /
# DATAVALS=             57119358 /
# MISSVALS=              9399402 /
# NSATPIX =                    0 /
# NSPIKES =                    0 /
# TOTVALS =             66518760 /
# PERCENTD=              85.8696 /
# DATASKEW=              1.78812 /
# DATAKURT=              7.63495 /
# DATAP01 =             -4.05289 /
# DATAP10 =            -0.618808 /
# DATAP25 =              1.67772 /
# DATAP75 =              34.2871 /
# DATAP90 =              94.2603 /
# DATAP95 =              116.731 /
# DATAP98 =              136.379 /
# DATAP99 =              148.820 /
# NEXP_PRP=                  276 /
# NEXP    =                  276 /
# NEXPOBS =                  759 /
# NRASTERP=                    1 /
# RASTYPDX=                    1 /
# RASTYPNX=                    1 /
# RASRPT  =                    1 /
# RASNRPT =                    1 /
# STEPS_AV=        0.00000000000 /
# STEPS_DV=        0.00000000000 /
# STEPT_AV=              3.05878 /
# STEPT_DV=             0.211566 /
# CADPL_AV=              3.05962 /
# CADPL_DV=             0.124518 /
# CADEX_AV=              3.05878 /
# CADEX_DV=             0.211374 /
# MISSOBS =                    0 /
# MISSRAS =                    0 /
# IPRPVER =        2.82999992371 /
# IPRPPDBV=        11.0000000000 /
# IPRPDVER=             20130925 /
# IPRPBVER=             20240225 /
# NWIN    =                    4 /
# TDET1   = 'FUV1    '           /
# TDESC1  = 'C II 1336'          /
# TWAVE1  =        1335.70996094 /
# TWMIN1  =        1332.70221016 /
# TWMAX1  =        1337.06349020 /
# TDMEAN1 =              2.26546 /
# TDRMS1  =              5.16511 /
# TDMEDN1 =              2.17495 /
# TDMIN1  =             -745.994 /
# TDMAX1  =              7084.28 /
# TDVALS1 =             15520004 /
# TMISSV1 =              2437936 /
# TSATPX1 =                    0 /
# TSPIKE1 =                    0 /
# TTOTV1  =             17957940 /
# TPCTD1  =              86.4242 /
# TDSKEW1 =              149.117 /
# TDKURT1 =              28610.3 /
# TDP01_1 =             -3.84428 /
# TDP10_1 =             -1.13839 /
# TDP25_1 =             0.411005 /
# TDP75_1 =              3.95679 /
# TDP90_1 =              5.64022 /
# TDP95_1 =              6.71489 /
# TDP98_1 =              7.94732 /
# TDP99_1 =              8.96022 /
# TSR1    =                   80 /
# TER1    =                  464 /
# TSC1    =                   40 /
# TEC1    =                  208 /
# IPRPFV1 =               100101 /
# IPRPGV1 =                   17 /
# IPRPPV1 =                  100 /
# TDET2   = 'FUV2    '           /
# TDESC2  = 'Si IV 1403'         /
# TWAVE2  =        1402.77001953 /
# TWMIN2  =        1400.25910787 /
# TWMAX2  =        1406.61910787 /
# TDMEAN2 =              1.39130 /
# TDRMS2  =              7.39279 /
# TDMEDN2 =              1.30667 /
# TDMIN2  =             -1260.72 /
# TDMAX2  =              12952.7 /
# TDVALS2 =             23259052 /
# TMISSV2 =              3412208 /
# TSATPX2 =                    0 /
# TSPIKE2 =                    0 /
# TTOTV2  =             26671260 /
# TPCTD2  =              87.2064 /
# TDSKEW2 =              57.2938 /
# TDKURT2 =              9163.16 /
# TDP01_2 =             -5.44840 /
# TDP10_2 =             -2.33586 /
# TDP25_2 =            -0.610179 /
# TDP75_2 =              3.26729 /
# TDP90_2 =              5.14574 /
# TDP95_2 =              6.35450 /
# TDP98_2 =              7.79836 /
# TDP99_2 =              8.91092 /
# TSR2    =                   80 /
# TER2    =                  464 /
# TSC2    =                 1807 /
# TEC2    =                 2057 /
# IPRPFV2 =               100101 /
# IPRPGV2 =                   17 /
# IPRPPV2 =                  100 /
# TDET3   = 'NUV     '           /
# TDESC3  = '2814    '           /
# TWAVE3  =        2814.53625601 /
# TWMIN3  =        2812.75405606 /
# TWMAX3  =        2816.31845596 /
# TDMEAN3 =              88.3567 /
# TDRMS3  =              33.9873 /
# TDMEDN3 =              86.6473 /
# TDMIN3  =             -835.691 /
# TDMAX3  =              479.731 /
# TDVALS3 =              6001641 /
# TMISSV3 =              1542819 /
# TSATPX3 =                    0 /
# TSPIKE3 =                    0 /
# TTOTV3  =              7544460 /
# TPCTD3  =              79.5503 /
# TDSKEW3 =             0.227859 /
# TDKURT3 =            -0.244946 /
# TDP01_3 =              17.0043 /
# TDP10_3 =              46.5803 /
# TDP25_3 =              63.2185 /
# TDP75_3 =              112.064 /
# TDP90_3 =              133.231 /
# TDP95_3 =              145.937 /
# TDP98_3 =              159.903 /
# TDP99_3 =              170.285 /
# TSR3    =                   80 /
# TER3    =                  464 /
# TSC3    =                  591 /
# TEC3    =                  661 /
# IPRPFV3 =               102839 /
# IPRPGV3 =                   16 /
# IPRPPV3 =                  102 /
# TDET4   = 'NUV     '           /
# TDESC4  = 'Mg II k 2796'       /
# TWAVE4  =        2796.19995117 /
# TWMIN4  =        2793.20077666 /
# TWMAX4  =        2800.02405646 /
# TDMEAN4 =              22.8145 /
# TDRMS4  =              13.3984 /
# TDMEDN4 =              20.6535 /
# TDMIN4  =             -82.4271 /
# TDMAX4  =              1646.72 /
# TDVALS4 =             12338661 /
# TMISSV4 =              2006439 /
# TSATPX4 =                    0 /
# TSPIKE4 =                    0 /
# TTOTV4  =             14345100 /
# TPCTD4  =              86.0131 /
# TDSKEW4 =              3.28131 /
# TDKURT4 =              20.1000 /
# TDP01_4 =              6.08959 /
# TDP10_4 =              10.7119 /
# TDP25_4 =              14.9300 /
# TDP75_4 =              26.8553 /
# TDP90_4 =              34.3670 /
# TDP95_4 =              44.2389 /
# TDP98_4 =              63.7663 /
# TDP99_4 =              78.6698 /
# TSR4    =                   80 /
# TER4    =                  464 /
# TSC4    =                  207 /
# TEC4    =                  341 /
# IPRPFV4 =               102839 /
# IPRPGV4 =                   16 /
# IPRPPV4 =                  102 /
# KEYWDDOC= 'http://www.lmsal.com/iris_science/irisfitskeywords.pdf' /
# HISTORY iris_prep  Dark v20130925; T=[-57.0,-57.0,-56.0,-57.0,1.7,1.0,1.0,0.9,2.
# HISTORY iris_prep  FUV background subtracted
# HISTORY iris_prep  Flat fielded with recnum  100101
# HISTORY iris_prep  Set permanently bad pixels to 0 prior to warping
# HISTORY iris_prep_geowave_roi  ran with rec_num 17 (FUVS), 18 (FUVL)
# HISTORY iris_prep_geowave_roi  boxwarp set to 1
# HISTORY iris_prep_geowave_roi  updated WCS parameters with iris_isp2wcs
# HISTORY iris_prep  Used iris_mk_pointdb ver 11
# HISTORY iris_prep         O I line wavelength shift [pix]:     -4.78
# HISTORY iris_prep    FUVS Fiducial midpoint Y shift [pix]:     -0.06
# HISTORY iris_prep  Pointing corr. w/AIA correl (solar x,y):    -5.32    -1.89
# HISTORY iris_prep         O I line wavelength shift [pix]:     -4.78
# HISTORY iris_prep    FUVL Fiducial midpoint Y shift [pix]:      0.01
# HISTORY iris_prep  Used INF_POLY_2D for warping
# HISTORY iris_prep VERSION:  2.83
# HISTORY iris_prep   ran on 20240411_181152
# HISTORY level2  Version L12-2019-08-08

# %%
print(hdul[~1].data[..., hdul[~1].header["TIME"]].shape)
# Out:
# (276,)

# %%
print(hdul[1].data.shape)
# Out:
# (276, 385, 169)

# %%
print(repr(hdul[1].header))
# Out:
# XTENSION= 'IMAGE   '           / IMAGE extension
# BITPIX  =                  -32 / Number of bits per data pixel
# NAXIS   =                    3 / Number of data axes
# NAXIS1  =                  169 /
# NAXIS2  =                  385 /
# NAXIS3  =                  276 /
# PCOUNT  =                    0 / No Group Parameters
# GCOUNT  =                    1 / One Data Group
# CDELT1  =      0.0259600002319 /
# CDELT2  =             0.332700 /
# CDELT3  =        0.00000000000 /
# CRPIX1  =              1.00000 /
# CRPIX2  =              193.000 /
# CRPIX3  =              138.000 /
# CRVAL1  =        1332.70221016 /
# CRVAL2  =             -1.84508 /
# CRVAL3  =              347.637 /
# CTYPE1  = 'WAVE    '           /
# CTYPE2  = 'HPLT-TAN'           /
# CTYPE3  = 'HPLN-TAN'           /
# CUNIT1  = 'Angstrom'           /
# CUNIT2  = 'arcsec  '           /
# CUNIT3  = 'arcsec  '           /
# PC1_1   =        1.00000000000 /
# PC1_2   =        0.00000000000 /
# PC2_1   =        0.00000000000 /
# PC2_2   =       0.999938607216 /
# PC3_1   =        0.00000000000 /
# PC3_2   =      0.0112917600200 /
# PC3_3   =       0.999938607216 /
# PC2_3   =     -0.0112917600200 /

# %%
hdul[~0].data[0]
# Out:
# ('3700201130', '3700200362', '1176', '3700201130', '1224', '/irisa/data/level1/2024/02/09/H0100/iris20240209_01110418_fuv.fits', '/irisa/data/level1/2024/02/09/H0100/iris20240209_01110412_nuv.fits-57.0,-57.0,-56.0,-57.0,1.7,1.0,1.0,0.9,2.4,2.0,1.7,2.3-57.0,-57.0,-56.0,-57.0,1.7,1.0,1.0,0.9,2.4,2.0,1.7,2.3')
